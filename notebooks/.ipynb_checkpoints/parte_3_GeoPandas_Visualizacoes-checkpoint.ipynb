# %%
#Importações

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from apoio.config import DADOS_LIMPOS
from apoio.graficos import SCATTER_ALPHA, PALETTE

import warnings
warnings.filterwarnings("ignore")

sns.set_theme(palette="bright", style="white")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       5 import pandas as pd
#       6 import seaborn as sns
# ----> 8 from Apoio.config import DADOS_LIMPOS
#       9 from Apoio.graficos import SCATTER_ALPHA, PALETTE
#      11 import warnings
#
# ModuleNotFoundError: No module named 'Apoio'
