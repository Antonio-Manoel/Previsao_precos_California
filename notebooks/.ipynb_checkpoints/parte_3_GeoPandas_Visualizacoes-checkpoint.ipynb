# %% [markdown]
# ## GeoPandas e Visualizações

# %%
#Importações

import folium
import geopandas as gpd
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from folium import plugins
from shapely.geometry import Point

from apoio.config import DADOS_LIMPOS, DADOS_GEO_ORIGINAIS
from apoio.graficos import SCATTER_ALPHA, PALETTE

import warnings
warnings.filterwarnings("ignore")

sns.set_theme(palette="bright", style="white")

# %% [markdown]
# #### Checagens básicas

# %%
df = pd.read_parquet(DADOS_LIMPOS)
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880             129
# 1    -122.22     37.86                  21         7099            1106
# 2    -122.26     37.84                  42         2555             665
# 3    -122.26     37.85                  50         1120             283
# 4    -122.26     37.84                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_household  population_per_household  \
# 0                  5             6.984127                  2.555556
# 1                  5             6.238137                  2.109842
# 2                  2             4.294118                  2.026891
# 3                  2             4.242424                  2.640152
# 4                  2             5.343675                  2.362768
#
#    bedrooms_per_room
# 0           0.146591
# 1           0.155797
# 2           0.260274
# 3           0.252679
# 4           0.203216

# %%
df.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 17559    -121.09     39.48                  25         1665             374
# 17560    -121.21     39.49                  18          697             150
# 17561    -121.22     39.43                  17         2254             485
# 17562    -121.32     39.43                  18         1860             409
# 17563    -121.24     39.37                  16         2785             616
#
#        population  households  median_income  median_house_value  \
# 17559         845         330         1.5603               78100
# 17560         356         114         2.5568               77100
# 17561        1007         433         1.7000               92300
# 17562         741         349         1.8672               84700
# 17563        1387         530         2.3886               89400
#
#       ocean_proximity  median_income_cat  rooms_per_household  \
# 17559          INLAND                  2             5.045455
# 17560          INLAND                  2             6.114035
# 17561          INLAND                  2             5.205543
# 17562          INLAND                  2             5.329513
# 17563          INLAND                  2             5.254717
#
#        population_per_household  bedrooms_per_room
# 17559                  2.560606           0.224625
# 17560                  3.122807           0.215208
# 17561                  2.325635           0.215173
# 17562                  2.123209           0.219892
# 17563                  2.616981           0.221185

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17564 entries, 0 to 17563
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17564 non-null  float64
#  1   latitude                  17564 non-null  float64
#  2   housing_median_age        17564 non-null  int8
#  3   total_rooms               17564 non-null  int16
#  4   total_bedrooms            17564 non-null  int16
#  5   population                17564 non-null  int16
#  6   households                17564 non-null  int16
#  7   median_income             17564 non-null  float64
#  8   median_house_value        17564 non-null  int32
#  9   ocean_proximity           17564 non-null  category
#  10  median_income_cat         17564 non-null  int64
#  11  rooms_per_household       17564 non-null  float64
#  12  population_per_household  17564 non-null  float64
#  13  bedrooms_per_room         17564 non-null  float64
# dtypes: category(1), float64(6), int16(4), int32(1), int64(1), int8(1)
# memory usage: 1.2 MB

# %% [markdown]
# #### Criando um GeoDataframe para o DataFrame que já temos

# %% [markdown]
# O GeoDataframe é uma extensão do Pandas para dados espaciais, como o DataFrame base é sobre condados do estado da Califórnia, sua utilização será útil para a visualização de mapas que surgirão adiante.

# %%
gdf_counties = gpd.read_file(DADOS_GEO_ORIGINAIS)

gdf_counties.head()
# Out:
#         name          fullname abbrev abcode ansi  \
# 0   Siskiyou   Siskiyou County    SIS   c047  093
# 1  Del Norte  Del Norte County    DNT   c008  015
# 2      Modoc      Modoc County    MOD   c025  049
# 3    Trinity    Trinity County    TRI   c053  105
# 4     Shasta     Shasta County    SHA   c045  089
#
#                                             geometry
# 0  POLYGON ((-121.44597 41.1839, -121.46238 41.18...
# 1  MULTIPOLYGON (((-124.19097 41.73619, -124.1933...
# 2  POLYGON ((-121.44784 41.99739, -121.42322 41.9...
# 3  POLYGON ((-122.66795 40.77637, -122.66814 40.7...
# 4  POLYGON ((-122.17328 40.37906, -122.17359 40.3...

# %% [markdown]
# Podemos notar novas colunas:
# - name
# - fullname
# - abbrev
# - abcode
# - ansi
# - geometry

# %% [markdown]
# **abcode**: Refere-se a um código de fronteira administrativa, usado para identificar divisões geográficas ou administrativas específicas, como estados, cidades ou condados.
#
# **ansi**: Refere-se a códigos padronizados pelo ANSI, usados principalmente nos EUA para identificar estados e condados. Esses códigos são uma forma de identificar regiões geográficas de maneira única e padronizada.

# %% [markdown]
# #### Criando um sistema de pontos para uma coluna de geometria espacial

# %%
pontos = [Point(long, lat) for long, lat in zip(df["longitude"], df["latitude"])]
pontos[:5]
# Out:
# [<POINT (-122.23 37.88)>,
#  <POINT (-122.22 37.86)>,
#  <POINT (-122.26 37.84)>,
#  <POINT (-122.26 37.85)>,
#  <POINT (-122.26 37.84)>]

# %%
gdf_base = gpd.GeoDataFrame(df, geometry=pontos)
gdf_base.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880             129
# 1    -122.22     37.86                  21         7099            1106
# 2    -122.26     37.84                  42         2555             665
# 3    -122.26     37.85                  50         1120             283
# 4    -122.26     37.84                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_household  population_per_household  \
# 0                  5             6.984127                  2.555556
# 1                  5             6.238137                  2.109842
# 2                  2             4.294118                  2.026891
# 3                  2             4.242424                  2.640152
# 4                  2             5.343675                  2.362768
#
#    bedrooms_per_room               geometry
# 0           0.146591  POINT (-122.23 37.88)
# 1           0.155797  POINT (-122.22 37.86)
# 2           0.260274  POINT (-122.26 37.84)
# 3           0.252679  POINT (-122.26 37.85)
# 4           0.203216  POINT (-122.26 37.84)

# %%
gdf_base.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 17564 entries, 0 to 17563
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17564 non-null  float64
#  1   latitude                  17564 non-null  float64
#  2   housing_median_age        17564 non-null  int8
#  3   total_rooms               17564 non-null  int16
#  4   total_bedrooms            17564 non-null  int16
#  5   population                17564 non-null  int16
#  6   households                17564 non-null  int16
#  7   median_income             17564 non-null  float64
#  8   median_house_value        17564 non-null  int32
#  9   ocean_proximity           17564 non-null  category
#  10  median_income_cat         17564 non-null  int64
#  11  rooms_per_household       17564 non-null  float64
#  12  population_per_household  17564 non-null  float64
#  13  bedrooms_per_room         17564 non-null  float64
#  14  geometry                  17564 non-null  geometry
# dtypes: category(1), float64(6), geometry(1), int16(4), int32(1), int64(1), int8(1)
# memory usage: 1.3 MB

# %% [markdown]
# #### Checando e atribuindo o CRS certo

# %% [markdown]
# Um Sistema de Referência de Coordenadas **(CRS)** define como dados geográficos são posicionados na Terra. É como uma “linguagem” que traduz coordenadas em locais reais no mapa.
#
# Essas coordenadas podem estar em latitude/longitude ou em medidas como metros, dependendo do sistema utilizado.
#
# O padrão mais comum é o **WGS 84**, usado globalmente (inclusive em GPS), e identificado pelo código **EPSG:4326**, que indica coordenadas em graus (latitude e longitude).
#
# Em projetos locais, outros sistemas podem ser usados para reduzir distorções. Quando diferentes arquivos usam CRSs distintos, é necessário convertê-los para garantir que se alinhem corretamente.
#
# Como a Terra é curva e os mapas são planos, entram em cena as projeções cartográficas, que transformam essa superfície em um plano, sempre com algum nível de distorção. Cada projeção prioriza aspectos diferentes, como áreas, formas ou distâncias.
#
# O CRS define onde os pontos estão na Terra, enquanto a projeção cartográfica define como esses pontos são representados no mapa.

# %%
gdf_base.crs

# %% [markdown]
# O **gdf_base** não possui **CRS** definido, então teremos que atribuir o mesmo do **gdf_counties** para ele:

# %%
gdf_counties.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gdf_base = gdf_base.set_crs(epsg=4326)

# %%
gdf_base.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# #### Vamos unir os 2 GeoDataframes em um só

# %%
gdf_joined = gpd.sjoin(gdf_base, gdf_counties, how="left", predicate="within")
gdf_joined.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880             129
# 1    -122.22     37.86                  21         7099            1106
# 2    -122.26     37.84                  42         2555             665
# 3    -122.26     37.85                  50         1120             283
# 4    -122.26     37.84                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    ...  rooms_per_household  population_per_household  bedrooms_per_room  \
# 0  ...             6.984127                  2.555556           0.146591
# 1  ...             6.238137                  2.109842           0.155797
# 2  ...             4.294118                  2.026891           0.260274
# 3  ...             4.242424                  2.640152           0.252679
# 4  ...             5.343675                  2.362768           0.203216
#
#                 geometry index_right     name        fullname abbrev abcode  \
# 0  POINT (-122.23 37.88)        34.0  Alameda  Alameda County    ALA   c001
# 1  POINT (-122.22 37.86)        34.0  Alameda  Alameda County    ALA   c001
# 2  POINT (-122.26 37.84)        34.0  Alameda  Alameda County    ALA   c001
# 3  POINT (-122.26 37.85)        34.0  Alameda  Alameda County    ALA   c001
# 4  POINT (-122.26 37.84)        34.0  Alameda  Alameda County    ALA   c001
#
#   ansi
# 0  001
# 1  001
# 2  001
# 3  001
# 4  001
#
# [5 rows x 21 columns]

# %%
gdf_joined.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 17559    -121.09     39.48                  25         1665             374
# 17560    -121.21     39.49                  18          697             150
# 17561    -121.22     39.43                  17         2254             485
# 17562    -121.32     39.43                  18         1860             409
# 17563    -121.24     39.37                  16         2785             616
#
#        population  households  median_income  median_house_value  \
# 17559         845         330         1.5603               78100
# 17560         356         114         2.5568               77100
# 17561        1007         433         1.7000               92300
# 17562         741         349         1.8672               84700
# 17563        1387         530         2.3886               89400
#
#       ocean_proximity  ...  rooms_per_household  population_per_household  \
# 17559          INLAND  ...             5.045455                  2.560606
# 17560          INLAND  ...             6.114035                  3.122807
# 17561          INLAND  ...             5.205543                  2.325635
# 17562          INLAND  ...             5.329513                  2.123209
# 17563          INLAND  ...             5.254717                  2.616981
#
#        bedrooms_per_room               geometry index_right  name  \
# 17559           0.224625  POINT (-121.09 39.48)        12.0  Yuba
# 17560           0.215208  POINT (-121.21 39.49)        12.0  Yuba
# 17561           0.215173  POINT (-121.22 39.43)        12.0  Yuba
# 17562           0.219892  POINT (-121.32 39.43)        12.0  Yuba
# 17563           0.221185  POINT (-121.24 39.37)        12.0  Yuba
#
#           fullname abbrev abcode ansi
# 17559  Yuba County    YUB   c058  115
# 17560  Yuba County    YUB   c058  115
# 17561  Yuba County    YUB   c058  115
# 17562  Yuba County    YUB   c058  115
# 17563  Yuba County    YUB   c058  115
#
# [5 rows x 21 columns]

# %%
gdf_joined.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 17564 entries, 0 to 17563
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17564 non-null  float64
#  1   latitude                  17564 non-null  float64
#  2   housing_median_age        17564 non-null  int8
#  3   total_rooms               17564 non-null  int16
#  4   total_bedrooms            17564 non-null  int16
#  5   population                17564 non-null  int16
#  6   households                17564 non-null  int16
#  7   median_income             17564 non-null  float64
#  8   median_house_value        17564 non-null  int32
#  9   ocean_proximity           17564 non-null  category
#  10  median_income_cat         17564 non-null  int64
#  11  rooms_per_household       17564 non-null  float64
#  12  population_per_household  17564 non-null  float64
#  13  bedrooms_per_room         17564 non-null  float64
#  14  geometry                  17564 non-null  geometry
#  15  index_right               17416 non-null  float64
#  16  name                      17416 non-null  object
#  17  fullname                  17416 non-null  object
#  18  abbrev                    17416 non-null  object
#  19  abcode                    17416 non-null  object
#  20  ansi                      17416 non-null  object
# dtypes: category(1), float64(7), geometry(1), int16(4), int32(1), int64(1), int8(1), object(5)
# memory usage: 2.2+ MB

# %% [markdown]
# #### Eliminando colunas desnecessárias para as projeções

# %%
gdf_joined = gdf_joined.drop(columns=["index_right", "fullname", "abcode", "ansi"])
gdf_joined.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880             129
# 1    -122.22     37.86                  21         7099            1106
# 2    -122.26     37.84                  42         2555             665
# 3    -122.26     37.85                  50         1120             283
# 4    -122.26     37.84                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_household  population_per_household  \
# 0                  5             6.984127                  2.555556
# 1                  5             6.238137                  2.109842
# 2                  2             4.294118                  2.026891
# 3                  2             4.242424                  2.640152
# 4                  2             5.343675                  2.362768
#
#    bedrooms_per_room               geometry     name abbrev
# 0           0.146591  POINT (-122.23 37.88)  Alameda    ALA
# 1           0.155797  POINT (-122.22 37.86)  Alameda    ALA
# 2           0.260274  POINT (-122.26 37.84)  Alameda    ALA
# 3           0.252679  POINT (-122.26 37.85)  Alameda    ALA
# 4           0.203216  POINT (-122.26 37.84)  Alameda    ALA

# %%
gdf_joined.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 17564 entries, 0 to 17563
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17564 non-null  float64
#  1   latitude                  17564 non-null  float64
#  2   housing_median_age        17564 non-null  int8
#  3   total_rooms               17564 non-null  int16
#  4   total_bedrooms            17564 non-null  int16
#  5   population                17564 non-null  int16
#  6   households                17564 non-null  int16
#  7   median_income             17564 non-null  float64
#  8   median_house_value        17564 non-null  int32
#  9   ocean_proximity           17564 non-null  category
#  10  median_income_cat         17564 non-null  int64
#  11  rooms_per_household       17564 non-null  float64
#  12  population_per_household  17564 non-null  float64
#  13  bedrooms_per_room         17564 non-null  float64
#  14  geometry                  17564 non-null  geometry
#  15  name                      17416 non-null  object
#  16  abbrev                    17416 non-null  object
# dtypes: category(1), float64(6), geometry(1), int16(4), int32(1), int64(1), int8(1), object(2)
# memory usage: 1.7+ MB

# %% [markdown]
# #### Verificando as colunas nulas e colocando dentro de uma variável

# %%
gdf_joined[gdf_joined.isnull().any(axis=1)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1507     -124.30     41.80                  19         2672             552
# 1508     -124.23     41.75                  11         3159             616
# 1511     -124.22     41.73                  28         3003             699
# 1517     -124.30     41.84                  17         2677             531
# 1521     -119.94     38.96                  20         1451             386
# ...          ...       ...                 ...          ...             ...
# 17198    -119.30     34.27                  17         1527             503
# 17199    -119.29     34.26                  32         3295             764
# 17201    -119.29     34.23                  22         2486             608
# 17232    -119.23     34.15                  18         6213            1188
# 17258    -119.21     34.12                  15         5778            1285
#
#        population  households  median_income  median_house_value  \
# 1507         1298         478         1.9797               85800
# 1508         1343         479         2.4805               73200
# 1511         1530         653         1.7038               78300
# 1517         1244         456         3.0313              103600
# 1521          467         255         1.5536              212500
# ...           ...         ...            ...                 ...
# 17198         688         423         1.6007              187500
# 17199        1344         600         3.6007              395500
# 17201         709         523         2.9018              275000
# 17232        2679        1000         3.7480              380400
# 17258        1722         829         4.3427              305800
#
#       ocean_proximity  median_income_cat  rooms_per_household  \
# 1507       NEAR OCEAN                  2             5.589958
# 1508       NEAR OCEAN                  2             6.594990
# 1511       NEAR OCEAN                  2             4.598775
# 1517       NEAR OCEAN                  3             5.870614
# 1521           INLAND                  2             5.690196
# ...               ...                ...                  ...
# 17198      NEAR OCEAN                  2             3.609929
# 17199      NEAR OCEAN                  3             5.491667
# 17201      NEAR OCEAN                  2             4.753346
# 17232      NEAR OCEAN                  3             6.213000
# 17258      NEAR OCEAN                  3             6.969843
#
#        population_per_household  bedrooms_per_room               geometry  \
# 1507                   2.715481           0.206587    POINT (-124.3 41.8)
# 1508                   2.803758           0.194998  POINT (-124.23 41.75)
# 1511                   2.343032           0.232767  POINT (-124.22 41.73)
# 1517                   2.728070           0.198356   POINT (-124.3 41.84)
# 1521                   1.831373           0.266023  POINT (-119.94 38.96)
# ...                         ...                ...                    ...
# 17198                  1.626478           0.329404   POINT (-119.3 34.27)
# 17199                  2.240000           0.231866  POINT (-119.29 34.26)
# 17201                  1.355641           0.244570  POINT (-119.29 34.23)
# 17232                  2.679000           0.191212  POINT (-119.23 34.15)
# 17258                  2.077201           0.222395  POINT (-119.21 34.12)
#
#       name abbrev
# 1507   NaN    NaN
# 1508   NaN    NaN
# 1511   NaN    NaN
# 1517   NaN    NaN
# 1521   NaN    NaN
# ...    ...    ...
# 17198  NaN    NaN
# 17199  NaN    NaN
# 17201  NaN    NaN
# 17232  NaN    NaN
# 17258  NaN    NaN
#
# [148 rows x 17 columns]

# %%
linhas_nulas = gdf_joined[gdf_joined.isnull().any(axis=1)].index
linhas_nulas
# Out:
# Index([ 1507,  1508,  1511,  1517,  1521,  2154,  2193,  2201,  2203,  2219,
#        ...
#        15747, 15748, 15752, 15755, 15756, 17198, 17199, 17201, 17232, 17258],
#       dtype='int64', length=148)

# %% [markdown]
# #### Criação de um centroide

# %% [markdown]
# O **centroide** é o ponto que representa o “centro” de uma área geográfica, como um município ou estado, mesmo quando o formato é irregular.
#
# Ele é calculado a partir das coordenadas da geometria, funcionando como uma espécie de ponto médio.
#
# No **GeoPandas**, o centroide pode ser obtido com `.centroid` e é muito útil para simplificar análises espaciais. Com ele, é possível, por exemplo, posicionar marcadores em mapas, comparar distâncias entre regiões ou representar áreas complexas de forma mais prática e intuitiva.

# %%
gdf_counties["centroid"] = gdf_counties.centroid
gdf_counties.head()
# Out:
#         name          fullname abbrev abcode ansi  \
# 0   Siskiyou   Siskiyou County    SIS   c047  093
# 1  Del Norte  Del Norte County    DNT   c008  015
# 2      Modoc      Modoc County    MOD   c025  049
# 3    Trinity    Trinity County    TRI   c053  105
# 4     Shasta     Shasta County    SHA   c045  089
#
#                                             geometry  \
# 0  POLYGON ((-121.44597 41.1839, -121.46238 41.18...
# 1  MULTIPOLYGON (((-124.19097 41.73619, -124.1933...
# 2  POLYGON ((-121.44784 41.99739, -121.42322 41.9...
# 3  POLYGON ((-122.66795 40.77637, -122.66814 40.7...
# 4  POLYGON ((-122.17328 40.37906, -122.17359 40.3...
#
#                       centroid
# 0  POINT (-122.54047 41.59268)
# 1  POINT (-123.89681 41.74299)
# 2  POINT (-120.72517 41.58987)
# 3  POINT (-123.11264 40.65063)
# 4  POINT (-122.04016 40.76344)

# %% [markdown]
# #### Criação de uma função para tratar das linhas com valores nulos

# %%
def condado_mais_proximo(linha):
    ponto = linha["geometry"]
    distancias = gdf_counties["centroid"].distance(ponto)
    idx_condado_mais_proximo = distancias.idxmin()
    condado_mais_proximo = gdf_counties.loc[idx_condado_mais_proximo]

    return condado_mais_proximo[["name", "abbrev"]]

# %%
gdf_joined.loc[linhas_nulas, ["name", "abbrev"]] = gdf_joined.loc[linhas_nulas].apply(condado_mais_proximo, axis=1)

# %%
gdf_joined.isnull().sum()
# Out:
# longitude                   0
# latitude                    0
# housing_median_age          0
# total_rooms                 0
# total_bedrooms              0
# population                  0
# households                  0
# median_income               0
# median_house_value          0
# ocean_proximity             0
# median_income_cat           0
# rooms_per_household         0
# population_per_household    0
# bedrooms_per_room           0
# geometry                    0
# name                        0
# abbrev                      0
# dtype: int64

# %% [markdown]
# Como visto, a função substituiu todos os valores nulos, pelos condados mais próximos de cada ponto

# %% [markdown]
# #### Criação de um mapa do gdf_counties com longitude e latitude

# %%
fig, ax = plt.subplots(figsize=(10, 7))

gdf_counties.plot(ax=ax, edgecolor="black", color="lightgreen")
ax.scatter(gdf_joined["longitude"], gdf_joined["latitude"], color="red", s=1, alpha=SCATTER_ALPHA)

for x, y, abbrev in zip(gdf_counties["centroid"].x, gdf_counties["centroid"].y, gdf_counties["abbrev"]):
    ax.text(x, y, abbrev, fontsize=8, ha="center", va="center", fontweight="bold")

plt.show()

# %% [markdown]
# #### Enriquecendo o gdf_counties com estatísticas calculadas a partir do gdf_joined

# %%
gdf_counties = gdf_counties.merge(gdf_joined.groupby("name").median(numeric_only=True), left_on="name", right_index=True)

# %% [markdown]
# O que foi feito acima?
#
# - Agrupando dados por condado (name)
# - Calculando a mediana das variáveis numéricas
# - Juntando isso no gdf_counties

# %%
gdf_counties.head()
# Out:
#         name          fullname abbrev abcode ansi  \
# 0   Siskiyou   Siskiyou County    SIS   c047  093
# 1  Del Norte  Del Norte County    DNT   c008  015
# 2      Modoc      Modoc County    MOD   c025  049
# 3    Trinity    Trinity County    TRI   c053  105
# 4     Shasta     Shasta County    SHA   c045  089
#
#                                             geometry  \
# 0  POLYGON ((-121.44597 41.1839, -121.46238 41.18...
# 1  MULTIPOLYGON (((-124.19097 41.73619, -124.1933...
# 2  POLYGON ((-121.44784 41.99739, -121.42322 41.9...
# 3  POLYGON ((-122.66795 40.77637, -122.66814 40.7...
# 4  POLYGON ((-122.17328 40.37906, -122.17359 40.3...
#
#                       centroid  longitude  latitude  housing_median_age  \
# 0  POINT (-122.54047 41.59268)   -122.545    41.615                23.0
# 1  POINT (-123.89681 41.74299)   -124.170    41.765                19.0
# 2  POINT (-120.72517 41.58987)   -120.530    41.575                22.0
# 3  POINT (-123.11264 40.65063)   -123.125    40.640                18.5
# 4  POINT (-122.04016 40.76344)   -122.350    40.570                19.0
#
#    total_rooms  total_bedrooms  population  households  median_income  \
# 0       2372.0           482.0      1111.0       427.0        2.17525
# 1       2705.5           560.5      1290.0       486.5        2.22895
# 2       2472.0           473.5       860.5       349.5        2.18775
# 3        954.0           211.5       369.5       154.0        1.90705
# 4       2251.0           463.0      1077.0       412.0        2.40790
#
#    median_house_value  median_income_cat  rooms_per_household  \
# 0             63950.0                2.0             5.848730
# 1             76650.0                2.0             5.523724
# 2             50250.0                2.0             6.891731
# 3             77100.0                2.0             6.116148
# 4             85200.0                2.0             5.487129
#
#    population_per_household  bedrooms_per_room
# 0                  2.534146           0.201014
# 1                  2.721776           0.207599
# 2                  2.537227           0.197889
# 3                  2.541760           0.225996
# 4                  2.714097           0.198684

# %% [markdown]
# #### Descobrindo a Moda (valor mais comum) de ocean_promity

# %%
counties_ocean_prox = gdf_joined[["name", "ocean_proximity"]].groupby("name").agg(pd.Series.mode)
counties_ocean_prox
# Out:
#                 ocean_proximity
# name
# Alameda                NEAR BAY
# Alpine                   INLAND
# Amador                   INLAND
# Butte                    INLAND
# Calaveras                INLAND
# Colusa                   INLAND
# Contra Costa           NEAR BAY
# Del Norte            NEAR OCEAN
# El Dorado                INLAND
# Fresno                   INLAND
# Glenn                    INLAND
# Humboldt             NEAR OCEAN
# Imperial                 INLAND
# Inyo                     INLAND
# Kern                     INLAND
# Kings                    INLAND
# Lake                     INLAND
# Lassen                   INLAND
# Los Angeles           <1H OCEAN
# Madera                   INLAND
# Marin                  NEAR BAY
# Mariposa                 INLAND
# Mendocino             <1H OCEAN
# Merced                   INLAND
# Modoc                    INLAND
# Mono                     INLAND
# Monterey              <1H OCEAN
# Napa                   NEAR BAY
# Nevada                   INLAND
# Orange                <1H OCEAN
# Placer                   INLAND
# Plumas                   INLAND
# Riverside                INLAND
# Sacramento               INLAND
# San Benito               INLAND
# San Bernardino           INLAND
# San Diego            NEAR OCEAN
# San Francisco          NEAR BAY
# San Joaquin              INLAND
# San Luis Obispo       <1H OCEAN
# San Mateo            NEAR OCEAN
# Santa Barbara        NEAR OCEAN
# Santa Clara           <1H OCEAN
# Santa Cruz           NEAR OCEAN
# Shasta                   INLAND
# Sierra                   INLAND
# Siskiyou                 INLAND
# Solano                   INLAND
# Sonoma                <1H OCEAN
# Stanislaus               INLAND
# Sutter                   INLAND
# Tehama                   INLAND
# Trinity                  INLAND
# Tulare                   INLAND
# Tuolumne                 INLAND
# Ventura               <1H OCEAN
# Yolo                     INLAND
# Yuba                     INLAND

# %% [markdown]
# #### Adicionando a variável anterior ao gdf_counties

# %%
gdf_counties = gdf_counties.merge(counties_ocean_prox, left_on="name", right_index=True)
gdf_counties.head()
# Out:
#         name          fullname abbrev abcode ansi  \
# 0   Siskiyou   Siskiyou County    SIS   c047  093
# 1  Del Norte  Del Norte County    DNT   c008  015
# 2      Modoc      Modoc County    MOD   c025  049
# 3    Trinity    Trinity County    TRI   c053  105
# 4     Shasta     Shasta County    SHA   c045  089
#
#                                             geometry  \
# 0  POLYGON ((-121.44597 41.1839, -121.46238 41.18...
# 1  MULTIPOLYGON (((-124.19097 41.73619, -124.1933...
# 2  POLYGON ((-121.44784 41.99739, -121.42322 41.9...
# 3  POLYGON ((-122.66795 40.77637, -122.66814 40.7...
# 4  POLYGON ((-122.17328 40.37906, -122.17359 40.3...
#
#                       centroid  longitude  latitude  housing_median_age  ...  \
# 0  POINT (-122.54047 41.59268)   -122.545    41.615                23.0  ...
# 1  POINT (-123.89681 41.74299)   -124.170    41.765                19.0  ...
# 2  POINT (-120.72517 41.58987)   -120.530    41.575                22.0  ...
# 3  POINT (-123.11264 40.65063)   -123.125    40.640                18.5  ...
# 4  POINT (-122.04016 40.76344)   -122.350    40.570                19.0  ...
#
#    total_bedrooms  population  households  median_income  median_house_value  \
# 0           482.0      1111.0       427.0        2.17525             63950.0
# 1           560.5      1290.0       486.5        2.22895             76650.0
# 2           473.5       860.5       349.5        2.18775             50250.0
# 3           211.5       369.5       154.0        1.90705             77100.0
# 4           463.0      1077.0       412.0        2.40790             85200.0
#
#    median_income_cat  rooms_per_household  population_per_household  \
# 0                2.0             5.848730                  2.534146
# 1                2.0             5.523724                  2.721776
# 2                2.0             6.891731                  2.537227
# 3                2.0             6.116148                  2.541760
# 4                2.0             5.487129                  2.714097
#
#    bedrooms_per_room  ocean_proximity
# 0           0.201014           INLAND
# 1           0.207599       NEAR OCEAN
# 2           0.197889           INLAND
# 3           0.225996           INLAND
# 4           0.198684           INLAND
#
# [5 rows x 21 columns]

# %%
gdf_counties.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   name                      58 non-null     object
#  1   fullname                  58 non-null     object
#  2   abbrev                    58 non-null     object
#  3   abcode                    58 non-null     object
#  4   ansi                      58 non-null     object
#  5   geometry                  58 non-null     geometry
#  6   centroid                  58 non-null     geometry
#  7   longitude                 58 non-null     float64
#  8   latitude                  58 non-null     float64
#  9   housing_median_age        58 non-null     float64
#  10  total_rooms               58 non-null     float64
#  11  total_bedrooms            58 non-null     float64
#  12  population                58 non-null     float64
#  13  households                58 non-null     float64
#  14  median_income             58 non-null     float64
#  15  median_house_value        58 non-null     float64
#  16  median_income_cat         58 non-null     float64
#  17  rooms_per_household       58 non-null     float64
#  18  population_per_household  58 non-null     float64
#  19  bedrooms_per_room         58 non-null     float64
#  20  ocean_proximity           58 non-null     category
# dtypes: category(1), float64(13), geometry(2), object(5)
# memory usage: 9.4+ KB

# %% [markdown]
# #### Recriando o mapa do gdf_counties

# %%
fig, ax = plt.subplots(figsize=(10, 7))

gdf_counties.plot(ax=ax, edgecolor="black", column="housing_median_age", cmap=PALETTE, legend=True,
                  legend_kwds={"label": "Median house value", "orientation": "vertical"})

for x, y, abbrev in zip(gdf_counties["centroid"].x, gdf_counties["centroid"].y, gdf_counties["abbrev"]):
    ax.text(x, y, abbrev, fontsize=8, ha="center", va="center", fontweight="bold")

plt.show()

# %% [markdown]
# Dessa vez, o olhar foi sobre a coluna **housing_median_age**, onde podemos ver os condados que possuem casas mais antigas.

# %% [markdown]
# #### Mapa para comparação de median_house_value e median_income

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 7))

gdf_counties.plot(ax=axs[0], edgecolor="black", column="housing_median_age", cmap=PALETTE, legend=True,
                  legend_kwds={"label": "Median house value", "orientation": "vertical"})

gdf_counties.plot(ax=axs[1], edgecolor="black", column="median_income", cmap="BrBG", legend=True,
                  legend_kwds={"label": "Median Income", "orientation": "vertical"})

for x, y, abbrev in zip(gdf_counties["centroid"].x, gdf_counties["centroid"].y, gdf_counties["abbrev"]):
    axs[0].text(x, y, abbrev, fontsize=8, ha="center", va="center", fontweight="bold")
    axs[1].text(x, y, abbrev, fontsize=8, ha="center", va="center", fontweight="bold")

plt.show()
